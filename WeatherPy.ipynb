# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

### Generate the Cities List by Using the `citipy` Library
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=150)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=150)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")

# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&units=metric&appid={weather_api_key}"

    #print(city_url)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        json = city_weather.json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = json['coord']['lat']
        city_lng = json['coord']['lon']
        city_max_temp = json['main']['temp_max']
        city_humidity = json['main']['humidity']
        city_clouds = json['clouds']['all']
        city_wind = json['wind']['speed']
        city_country = json['sys']['country']
        city_date = datetime.fromtimestamp(json['dt'])
        

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

pprint(city_data)
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Number of cities in the list: 115
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 2 of Set 1 | zaozersk
# Processing Record 3 of Set 1 | newman
# Processing Record 4 of Set 1 | xiva
# Processing Record 5 of Set 1 | kyzyl-mazhalyk
# Processing Record 6 of Set 1 | yanam
# Processing Record 7 of Set 1 | bilibino
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | tangalle
# Processing Record 10 of Set 1 | labrador city
# Processing Record 11 of Set 1 | baneh
# Processing Record 12 of Set 1 | lorengau
# Processing Record 13 of Set 1 | blackmans bay
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | grytviken
# Processing Record 16 of Set 1 | al bardiyah
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | waitangi
# Processing Record 19 of Set 1 | tarko-sale
# Processing Record 20 of Set 1 | st. john's
# Processing Record 21 of Set 1 | aasiaat
# Processing Record 22 of Set 1 | aksu
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | meulaboh
# Processing Record 26 of Set 1 | adamstown
# Processing Record 27 of Set 1 | badger
# Processing Record 28 of Set 1 | buritis
# Processing Record 29 of Set 1 | hamilton
# Processing Record 30 of Set 1 | polyarnyy
# Processing Record 31 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 32 of Set 1 | nassau village-ratliff
# Processing Record 33 of Set 1 | port moresby
# Processing Record 34 of Set 1 | alofi
# Processing Record 35 of Set 1 | paraiso
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | yaren
# Processing Record 38 of Set 1 | pisco
# Processing Record 39 of Set 1 | qarazhal
# Processing Record 40 of Set 1 | alta
# Processing Record 41 of Set 1 | portland
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | dauphin
# Processing Record 44 of Set 1 | coquimbo
# Processing Record 45 of Set 1 | prado
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | az zubayr
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | puerto natales
# Processing Record 0 of Set 2 | albany
# Processing Record 1 of Set 2 | wailua homesteads
# Processing Record 2 of Set 2 | san antonio de pale
# Processing Record 3 of Set 2 | lihue
# Processing Record 4 of Set 2 | borovskoy
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | tabou
# Processing Record 7 of Set 2 | papao
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | colonia
# Processing Record 10 of Set 2 | margaret river
# Processing Record 11 of Set 2 | chibougamau
# Processing Record 12 of Set 2 | grand baie
# Processing Record 13 of Set 2 | iskateley
# Processing Record 14 of Set 2 | kearney
# Processing Record 15 of Set 2 | vorgashor
# Processing Record 16 of Set 2 | rampur
# Processing Record 17 of Set 2 | egilsstadir
# Processing Record 18 of Set 2 | buala
# Processing Record 19 of Set 2 | al fqih ben calah
# Processing Record 20 of Set 2 | pankshin
# Processing Record 21 of Set 2 | west island
# Processing Record 22 of Set 2 | dryden
# Processing Record 23 of Set 2 | qaqortoq
# Processing Record 24 of Set 2 | weno
# Processing Record 25 of Set 2 | maridi
# Processing Record 26 of Set 2 | iqaluit
# Processing Record 27 of Set 2 | anadyr
# Processing Record 28 of Set 2 | la'ie
# Processing Record 29 of Set 2 | goshainganj
# Processing Record 30 of Set 2 | galeana
# Processing Record 31 of Set 2 | whitehorse
# Processing Record 32 of Set 2 | tralee
# Processing Record 33 of Set 2 | northam
# Processing Record 34 of Set 2 | mwene-ditu
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | cockburn town
# Processing Record 37 of Set 2 | enewetak
# Processing Record 38 of Set 2 | remire-montjoly
# Processing Record 39 of Set 2 | kresttsy
# Processing Record 40 of Set 2 | palapag
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | antsiranana
# Processing Record 43 of Set 2 | rantauprapat
# Processing Record 44 of Set 2 | horta
# Processing Record 45 of Set 2 | morozovsk
# Processing Record 46 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 47 of Set 2 | stanley
# Processing Record 48 of Set 2 | vikulovo
# Processing Record 49 of Set 2 | jayapura
# Processing Record 0 of Set 3 | ambon
# Processing Record 1 of Set 3 | vadso
# Processing Record 2 of Set 3 | nakhon thai
# Processing Record 3 of Set 3 | inhambane
# Processing Record 4 of Set 3 | margate
# Processing Record 5 of Set 3 | alice springs
# Processing Record 6 of Set 3 | nyurba
# Processing Record 7 of Set 3 | gagliano del capo
# Processing Record 8 of Set 3 | punta arenas
# Processing Record 9 of Set 3 | komsomol'sk
# Processing Record 10 of Set 3 | vilyuchinsk
# Processing Record 11 of Set 3 | aykhal
# Processing Record 12 of Set 3 | port blair
# Processing Record 13 of Set 3 | nar'yan-mar
# Processing Record 14 of Set 3 | sitka
# [{'City': 'petropavlovsk-kamchatsky',
#   'Cloudiness': 20,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 44),
#   'Humidity': 62,
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 10.33,
#   'Wind Speed': 2},
#  {'City': 'zaozersk',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 45),
#   'Humidity': 96,
#   'Lat': 69.4005,
#   'Lng': 32.4476,
#   'Max Temp': 5.58,
#   'Wind Speed': 6.8},
#  {'City': 'newman',
#   'Cloudiness': 93,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 45),
#   'Humidity': 19,
#   'Lat': 37.3138,
#   'Lng': -121.0208,
#   'Max Temp': 26.19,
#   'Wind Speed': 3.05},
#  {'City': 'xiva',
#   'Cloudiness': 0,
#   'Country': 'UZ',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 45),
#   'Humidity': 32,
#   'Lat': 41.3783,
#   'Lng': 60.3639,
#   'Max Temp': 12.99,
#   'Wind Speed': 2.86},
#  {'City': 'kyzyl-mazhalyk',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 45),
#   'Humidity': 53,
#   'Lat': 51.1333,
#   'Lng': 90.6,
#   'Max Temp': 2.75,
#   'Wind Speed': 0.68},
#  {'City': 'yanam',
#   'Cloudiness': 89,
#   'Country': 'IN',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 45),
#   'Humidity': 94,
#   'Lat': 16.7333,
#   'Lng': 82.2167,
#   'Max Temp': 25.45,
#   'Wind Speed': 0.56},
#  {'City': 'bilibino',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 46),
#   'Humidity': 82,
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -1.87,
#   'Wind Speed': 0.22},
#  {'City': 'lebu',
#   'Cloudiness': 100,
#   'Country': 'CL',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 46),
#   'Humidity': 84,
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 9.13,
#   'Wind Speed': 3.72},
#  {'City': 'tangalle',
#   'Cloudiness': 91,
#   'Country': 'LK',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 46),
#   'Humidity': 87,
#   'Lat': 6.024,
#   'Lng': 80.7911,
#   'Max Temp': 26.09,
#   'Wind Speed': 4.59},
#  {'City': 'labrador city',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 46),
#   'Humidity': 62,
#   'Lat': 52.9463,
#   'Lng': -66.9114,
#   'Max Temp': 10.95,
#   'Wind Speed': 4.63},
#  {'City': 'baneh',
#   'Cloudiness': 23,
#   'Country': 'IR',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 46),
#   'Humidity': 67,
#   'Lat': 35.9975,
#   'Lng': 45.8853,
#   'Max Temp': 14.84,
#   'Wind Speed': 3.16},
#  {'City': 'lorengau',
#   'Cloudiness': 100,
#   'Country': 'PG',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 46),
#   'Humidity': 82,
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 27.54,
#   'Wind Speed': 4.21},
#  {'City': 'blackmans bay',
#   'Cloudiness': 46,
#   'Country': 'AU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 47),
#   'Humidity': 89,
#   'Lat': -43.0167,
#   'Lng': 147.3167,
#   'Max Temp': 5.96,
#   'Wind Speed': 1.8},
#  {'City': 'port-aux-francais',
#   'Cloudiness': 100,
#   'Country': 'TF',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 21),
#   'Humidity': 67,
#   'Lat': -49.35,
#   'Lng': 70.2167,
#   'Max Temp': 1.2,
#   'Wind Speed': 12.77},
#  {'City': 'grytviken',
#   'Cloudiness': 17,
#   'Country': 'GS',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 28),
#   'Humidity': 76,
#   'Lat': -54.2811,
#   'Lng': -36.5092,
#   'Max Temp': -8.12,
#   'Wind Speed': 4.43},
#  {'City': 'al bardiyah',
#   'Cloudiness': 0,
#   'Country': 'LY',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 47),
#   'Humidity': 81,
#   'Lat': 31.7561,
#   'Lng': 25.0865,
#   'Max Temp': 24.45,
#   'Wind Speed': 2.14},
#  {'City': 'port elizabeth',
#   'Cloudiness': 75,
#   'Country': 'ZA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 43, 18),
#   'Humidity': 83,
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 16.72,
#   'Wind Speed': 3.09},
#  {'City': 'waitangi',
#   'Cloudiness': 100,
#   'Country': 'NZ',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 24),
#   'Humidity': 97,
#   'Lat': -43.9535,
#   'Lng': -176.5597,
#   'Max Temp': 13.79,
#   'Wind Speed': 4.47},
#  {'City': 'tarko-sale',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 44, 23),
#   'Humidity': 86,
#   'Lat': 64.9225,
#   'Lng': 77.785,
#   'Max Temp': 11.11,
#   'Wind Speed': 10.28},
#  {'City': "st. john's",
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 48),
#   'Humidity': 83,
#   'Lat': 47.5649,
#   'Lng': -52.7093,
#   'Max Temp': 8.71,
#   'Wind Speed': 9.39},
#  {'City': 'aasiaat',
#   'Cloudiness': 96,
#   'Country': 'GL',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 48),
#   'Humidity': 88,
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': -2.39,
#   'Wind Speed': 3.12},
#  {'City': 'aksu',
#   'Cloudiness': 93,
#   'Country': 'CN',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 48),
#   'Humidity': 33,
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Max Temp': 15.85,
#   'Wind Speed': 2.08},
#  {'City': 'jamestown',
#   'Cloudiness': 100,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 48),
#   'Humidity': 75,
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 19.8,
#   'Wind Speed': 3.6},
#  {'City': 'ushuaia',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 22),
#   'Humidity': 43,
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 9.81,
#   'Wind Speed': 3.09},
#  {'City': 'meulaboh',
#   'Cloudiness': 100,
#   'Country': 'ID',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 48),
#   'Humidity': 90,
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 23.72,
#   'Wind Speed': 2.02},
#  {'City': 'adamstown',
#   'Cloudiness': 78,
#   'Country': 'PN',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 20),
#   'Humidity': 74,
#   'Lat': -25.066,
#   'Lng': -130.1015,
#   'Max Temp': 20.78,
#   'Wind Speed': 9.25},
#  {'City': 'badger',
#   'Cloudiness': 20,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 49),
#   'Humidity': 56,
#   'Lat': 64.8,
#   'Lng': -147.5333,
#   'Max Temp': 9.52,
#   'Wind Speed': 0.89},
#  {'City': 'buritis',
#   'Cloudiness': 77,
#   'Country': 'BR',
#   'Date': datetime.datetime(2023, 9, 25, 22, 42, 11),
#   'Humidity': 21,
#   'Lat': -15.6178,
#   'Lng': -46.4233,
#   'Max Temp': 33.77,
#   'Wind Speed': 0.5},
#  {'City': 'hamilton',
#   'Cloudiness': 20,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 49),
#   'Humidity': 62,
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 27.22,
#   'Wind Speed': 3.09},
#  {'City': 'polyarnyy',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 27),
#   'Humidity': 93,
#   'Lat': 69.1989,
#   'Lng': 33.4478,
#   'Max Temp': 6.57,
#   'Wind Speed': 6.57},
#  {'City': 'nassau village-ratliff',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 50),
#   'Humidity': 57,
#   'Lat': 30.5111,
#   'Lng': -81.8093,
#   'Max Temp': 30.99,
#   'Wind Speed': 3.6},
#  {'City': 'port moresby',
#   'Cloudiness': 100,
#   'Country': 'PG',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 50),
#   'Humidity': 94,
#   'Lat': -9.4431,
#   'Lng': 147.1797,
#   'Max Temp': 23.68,
#   'Wind Speed': 10.29},
#  {'City': 'alofi',
#   'Cloudiness': 40,
#   'Country': 'NU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 50),
#   'Humidity': 57,
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 25.94,
#   'Wind Speed': 8.75},
#  {'City': 'paraiso',
#   'Cloudiness': 91,
#   'Country': 'CR',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 50),
#   'Humidity': 76,
#   'Lat': 9.8383,
#   'Lng': -83.8656,
#   'Max Temp': 22.2,
#   'Wind Speed': 0.91},
#  {'City': 'bethel',
#   'Cloudiness': 100,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 22),
#   'Humidity': 88,
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 15.2,
#   'Wind Speed': 2.24},
#  {'City': 'yaren',
#   'Cloudiness': 100,
#   'Country': 'NR',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 50),
#   'Humidity': 74,
#   'Lat': -0.5472,
#   'Lng': 166.916,
#   'Max Temp': 28.07,
#   'Wind Speed': 2.87},
#  {'City': 'pisco',
#   'Cloudiness': 0,
#   'Country': 'PE',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 51),
#   'Humidity': 73,
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 21.03,
#   'Wind Speed': 9.77},
#  {'City': 'qarazhal',
#   'Cloudiness': 1,
#   'Country': 'KZ',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 51),
#   'Humidity': 64,
#   'Lat': 48.0078,
#   'Lng': 70.7903,
#   'Max Temp': 12.45,
#   'Wind Speed': 1.57},
#  {'City': 'alta',
#   'Cloudiness': 75,
#   'Country': 'NO',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 51),
#   'Humidity': 87,
#   'Lat': 69.9689,
#   'Lng': 23.2717,
#   'Max Temp': 7.59,
#   'Wind Speed': 0.51},
#  {'City': 'portland',
#   'Cloudiness': 100,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 43, 18),
#   'Humidity': 83,
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 18.45,
#   'Wind Speed': 4.02},
#  {'City': 'saint-philippe',
#   'Cloudiness': 38,
#   'Country': 'RE',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 51),
#   'Humidity': 75,
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 19.77,
#   'Wind Speed': 4.65},
#  {'City': 'dauphin',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 51),
#   'Humidity': 77,
#   'Lat': 51.1494,
#   'Lng': -100.0502,
#   'Max Temp': 19.08,
#   'Wind Speed': 2.06},
#  {'City': 'coquimbo',
#   'Cloudiness': 0,
#   'Country': 'CL',
#   'Date': datetime.datetime(2023, 9, 25, 22, 44, 13),
#   'Humidity': 59,
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 16.85,
#   'Wind Speed': 7.72},
#  {'City': 'prado',
#   'Cloudiness': 3,
#   'Country': 'BR',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 52),
#   'Humidity': 87,
#   'Lat': -17.3411,
#   'Lng': -39.2208,
#   'Max Temp': 24.83,
#   'Wind Speed': 6.98},
#  {'City': 'port alfred',
#   'Cloudiness': 91,
#   'Country': 'ZA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 29),
#   'Humidity': 70,
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 16.39,
#   'Wind Speed': 3.79},
#  {'City': 'bredasdorp',
#   'Cloudiness': 57,
#   'Country': 'ZA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 23),
#   'Humidity': 86,
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 12.14,
#   'Wind Speed': 4.73},
#  {'City': 'az zubayr',
#   'Cloudiness': 0,
#   'Country': 'IQ',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 31),
#   'Humidity': 51,
#   'Lat': 30.3945,
#   'Lng': 47.7011,
#   'Max Temp': 28.92,
#   'Wind Speed': 3.09},
#  {'City': 'carnarvon',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 52),
#   'Humidity': 60,
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 15.96,
#   'Wind Speed': 9.44},
#  {'City': 'puerto natales',
#   'Cloudiness': 26,
#   'Country': 'CL',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 19),
#   'Humidity': 67,
#   'Lat': -51.7236,
#   'Lng': -72.4875,
#   'Max Temp': 6.32,
#   'Wind Speed': 2.98},
#  {'City': 'albany',
#   'Cloudiness': 96,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 32),
#   'Humidity': 80,
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 18.52,
#   'Wind Speed': 0.45},
#  {'City': 'wailua homesteads',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 53),
#   'Humidity': 62,
#   'Lat': 22.0669,
#   'Lng': -159.378,
#   'Max Temp': 28.44,
#   'Wind Speed': 5.66},
#  {'City': 'san antonio de pale',
#   'Cloudiness': 71,
#   'Country': 'GQ',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 21),
#   'Humidity': 86,
#   'Lat': -1.4014,
#   'Lng': 5.6325,
#   'Max Temp': 24.77,
#   'Wind Speed': 6.07},
#  {'City': 'lihue',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 53),
#   'Humidity': 62,
#   'Lat': 21.9789,
#   'Lng': -159.3672,
#   'Max Temp': 28.77,
#   'Wind Speed': 5.66},
#  {'City': 'borovskoy',
#   'Cloudiness': 5,
#   'Country': 'KZ',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 53),
#   'Humidity': 77,
#   'Lat': 53.8,
#   'Lng': 64.15,
#   'Max Temp': 13.91,
#   'Wind Speed': 3.02},
#  {'City': 'puerto ayora',
#   'Cloudiness': 85,
#   'Country': 'EC',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 27),
#   'Humidity': 91,
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 30.98,
#   'Wind Speed': 3.13},
#  {'City': 'tabou',
#   'Cloudiness': 57,
#   'Country': 'CI',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 54),
#   'Humidity': 91,
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 24.57,
#   'Wind Speed': 2.87},
#  {'City': 'papao',
#   'Cloudiness': 100,
#   'Country': 'PF',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 54),
#   'Humidity': 89,
#   'Lat': -17.75,
#   'Lng': -149.55,
#   'Max Temp': 24.82,
#   'Wind Speed': 8.5},
#  {'City': 'hithadhoo',
#   'Cloudiness': 79,
#   'Country': 'MV',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 54),
#   'Humidity': 77,
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 27.38,
#   'Wind Speed': 2.96},
#  {'City': 'colonia',
#   'Cloudiness': 0,
#   'Country': 'DE',
#   'Date': datetime.datetime(2023, 9, 25, 22, 45, 26),
#   'Humidity': 76,
#   'Lat': 50.9333,
#   'Lng': 6.95,
#   'Max Temp': 16.57,
#   'Wind Speed': 1.03},
#  {'City': 'margaret river',
#   'Cloudiness': 9,
#   'Country': 'AU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 36),
#   'Humidity': 76,
#   'Lat': -33.95,
#   'Lng': 115.0667,
#   'Max Temp': 11.66,
#   'Wind Speed': 0.77},
#  {'City': 'chibougamau',
#   'Cloudiness': 0,
#   'Country': 'CA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 22),
#   'Humidity': 42,
#   'Lat': 49.9168,
#   'Lng': -74.3659,
#   'Max Temp': 16.79,
#   'Wind Speed': 4.12},
#  {'City': 'grand baie',
#   'Cloudiness': 0,
#   'Country': 'MU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 55),
#   'Humidity': 74,
#   'Lat': -20.0182,
#   'Lng': 57.5802,
#   'Max Temp': 22.26,
#   'Wind Speed': 0.45},
#  {'City': 'iskateley',
#   'Cloudiness': 33,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 55),
#   'Humidity': 85,
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 4,
#   'Wind Speed': 5.46},
#  {'City': 'kearney',
#   'Cloudiness': 0,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 55),
#   'Humidity': 38,
#   'Lat': 40.6995,
#   'Lng': -99.0815,
#   'Max Temp': 29.93,
#   'Wind Speed': 1.54},
#  {'City': 'vorgashor',
#   'Cloudiness': 57,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 33),
#   'Humidity': 94,
#   'Lat': 67.5833,
#   'Lng': 63.95,
#   'Max Temp': 0.91,
#   'Wind Speed': 3.53},
#  {'City': 'rampur',
#   'Cloudiness': 0,
#   'Country': 'IN',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 55),
#   'Humidity': 85,
#   'Lat': 28.8167,
#   'Lng': 79.0333,
#   'Max Temp': 23.94,
#   'Wind Speed': 1.32},
#  {'City': 'egilsstadir',
#   'Cloudiness': 100,
#   'Country': 'IS',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 55),
#   'Humidity': 100,
#   'Lat': 65.2653,
#   'Lng': -14.3948,
#   'Max Temp': 6.95,
#   'Wind Speed': 6.17},
#  {'City': 'buala',
#   'Cloudiness': 92,
#   'Country': 'SB',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 56),
#   'Humidity': 74,
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 27.75,
#   'Wind Speed': 5.53},
#  {'City': 'al fqih ben calah',
#   'Cloudiness': 1,
#   'Country': 'MA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 56),
#   'Humidity': 44,
#   'Lat': 32.5009,
#   'Lng': -6.6906,
#   'Max Temp': 25.47,
#   'Wind Speed': 3.79},
#  {'City': 'pankshin',
#   'Cloudiness': 22,
#   'Country': 'NG',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 56),
#   'Humidity': 86,
#   'Lat': 9.3333,
#   'Lng': 9.45,
#   'Max Temp': 19.39,
#   'Wind Speed': 1.38},
#  {'City': 'west island',
#   'Cloudiness': 100,
#   'Country': 'CC',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 23),
#   'Humidity': 78,
#   'Lat': -12.1568,
#   'Lng': 96.8225,
#   'Max Temp': 24.99,
#   'Wind Speed': 5.14},
#  {'City': 'dryden',
#   'Cloudiness': 0,
#   'Country': 'CA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 56),
#   'Humidity': 33,
#   'Lat': 49.7833,
#   'Lng': -92.7503,
#   'Max Temp': 23.16,
#   'Wind Speed': 4.12},
#  {'City': 'qaqortoq',
#   'Cloudiness': 50,
#   'Country': 'GL',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 57),
#   'Humidity': 55,
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 2.06,
#   'Wind Speed': 2.46},
#  {'City': 'weno',
#   'Cloudiness': 100,
#   'Country': 'FM',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 57),
#   'Humidity': 94,
#   'Lat': 7.4515,
#   'Lng': 151.8468,
#   'Max Temp': 26.97,
#   'Wind Speed': 1.54},
#  {'City': 'maridi',
#   'Cloudiness': 100,
#   'Country': 'SS',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 57),
#   'Humidity': 94,
#   'Lat': 4.9158,
#   'Lng': 29.4742,
#   'Max Temp': 18.98,
#   'Wind Speed': 0.87},
#  {'City': 'iqaluit',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 37),
#   'Humidity': 93,
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 4.85,
#   'Wind Speed': 5.66},
#  {'City': 'anadyr',
#   'Cloudiness': 75,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 57),
#   'Humidity': 100,
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 2.28,
#   'Wind Speed': 5},
#  {'City': "la'ie",
#   'Cloudiness': 11,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 33),
#   'Humidity': 68,
#   'Lat': 21.6477,
#   'Lng': -157.9253,
#   'Max Temp': 30.98,
#   'Wind Speed': 7.04},
#  {'City': 'goshainganj',
#   'Cloudiness': 30,
#   'Country': 'IN',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 57),
#   'Humidity': 91,
#   'Lat': 26.5833,
#   'Lng': 82.3833,
#   'Max Temp': 24.61,
#   'Wind Speed': 2.45},
#  {'City': 'galeana',
#   'Cloudiness': 0,
#   'Country': 'MX',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 58),
#   'Humidity': 30,
#   'Lat': 24.8333,
#   'Lng': -100.0667,
#   'Max Temp': 27.3,
#   'Wind Speed': 5.87},
#  {'City': 'whitehorse',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 58),
#   'Humidity': 88,
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': 4.43,
#   'Wind Speed': 3.09},
#  {'City': 'tralee',
#   'Cloudiness': 69,
#   'Country': 'IE',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 58),
#   'Humidity': 78,
#   'Lat': 52.2704,
#   'Lng': -9.7026,
#   'Max Temp': 15.48,
#   'Wind Speed': 7.25},
#  {'City': 'northam',
#   'Cloudiness': 91,
#   'Country': 'GB',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 58),
#   'Humidity': 92,
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 14.66,
#   'Wind Speed': 5.21},
#  {'City': 'mwene-ditu',
#   'Cloudiness': 53,
#   'Country': 'CD',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 58),
#   'Humidity': 64,
#   'Lat': -7,
#   'Lng': 23.45,
#   'Max Temp': 23.18,
#   'Wind Speed': 1.64},
#  {'City': 'georgetown',
#   'Cloudiness': 20,
#   'Country': 'MY',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 59),
#   'Humidity': 98,
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 25.57,
#   'Wind Speed': 1.54},
#  {'City': 'cockburn town',
#   'Cloudiness': 100,
#   'Country': 'TC',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 36),
#   'Humidity': 79,
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 29.12,
#   'Wind Speed': 7.75},
#  {'City': 'enewetak',
#   'Cloudiness': 99,
#   'Country': 'MH',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 59),
#   'Humidity': 77,
#   'Lat': 11.3474,
#   'Lng': 162.3373,
#   'Max Temp': 29.02,
#   'Wind Speed': 5.1},
#  {'City': 'remire-montjoly',
#   'Cloudiness': 0,
#   'Country': 'GF',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 59),
#   'Humidity': 79,
#   'Lat': 4.9167,
#   'Lng': -52.2667,
#   'Max Temp': 29.02,
#   'Wind Speed': 3.6},
#  {'City': 'kresttsy',
#   'Cloudiness': 89,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 45, 57),
#   'Humidity': 88,
#   'Lat': 58.2452,
#   'Lng': 32.5165,
#   'Max Temp': 8.52,
#   'Wind Speed': 1.98},
#  {'City': 'palapag',
#   'Cloudiness': 74,
#   'Country': 'PH',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 59),
#   'Humidity': 88,
#   'Lat': 12.5458,
#   'Lng': 125.1147,
#   'Max Temp': 25.65,
#   'Wind Speed': 2.23},
#  {'City': 'tiksi',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 35),
#   'Humidity': 96,
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 3.77,
#   'Wind Speed': 10.38},
#  {'City': 'antsiranana',
#   'Cloudiness': 14,
#   'Country': 'MG',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47),
#   'Humidity': 78,
#   'Lat': -12.2787,
#   'Lng': 49.2917,
#   'Max Temp': 22.69,
#   'Wind Speed': 7.31},
#  {'City': 'rantauprapat',
#   'Cloudiness': 100,
#   'Country': 'ID',
#   'Date': datetime.datetime(2023, 9, 25, 22, 45, 59),
#   'Humidity': 91,
#   'Lat': 2.1,
#   'Lng': 99.8333,
#   'Max Temp': 22.48,
#   'Wind Speed': 0.93},
#  {'City': 'horta',
#   'Cloudiness': 93,
#   'Country': 'PT',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47),
#   'Humidity': 87,
#   'Lat': 38.5333,
#   'Lng': -28.6333,
#   'Max Temp': 21.12,
#   'Wind Speed': 3.58},
#  {'City': 'morozovsk',
#   'Cloudiness': 8,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 43, 28),
#   'Humidity': 48,
#   'Lat': 48.3539,
#   'Lng': 41.8261,
#   'Max Temp': 17.61,
#   'Wind Speed': 3.24},
#  {'City': 'stanley',
#   'Cloudiness': 0,
#   'Country': 'GB',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 25),
#   'Humidity': 85,
#   'Lat': 54.868,
#   'Lng': -1.6985,
#   'Max Temp': 12.1,
#   'Wind Speed': 1.03},
#  {'City': 'vikulovo',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 1),
#   'Humidity': 64,
#   'Lat': 56.8167,
#   'Lng': 70.6107,
#   'Max Temp': 11.35,
#   'Wind Speed': 2.4},
#  {'City': 'jayapura',
#   'Cloudiness': 99,
#   'Country': 'ID',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 1),
#   'Humidity': 92,
#   'Lat': -2.5333,
#   'Lng': 140.7,
#   'Max Temp': 24.66,
#   'Wind Speed': 3.36},
#  {'City': 'ambon',
#   'Cloudiness': 40,
#   'Country': 'ID',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 1),
#   'Humidity': 95,
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 26.6,
#   'Wind Speed': 3.09},
#  {'City': 'vadso',
#   'Cloudiness': 75,
#   'Country': 'NO',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 33),
#   'Humidity': 87,
#   'Lat': 70.0744,
#   'Lng': 29.7487,
#   'Max Temp': 7.09,
#   'Wind Speed': 8.23},
#  {'City': 'nakhon thai',
#   'Cloudiness': 86,
#   'Country': 'TH',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 1),
#   'Humidity': 91,
#   'Lat': 17.1006,
#   'Lng': 100.8374,
#   'Max Temp': 23.56,
#   'Wind Speed': 1.06},
#  {'City': 'inhambane',
#   'Cloudiness': 2,
#   'Country': 'MZ',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 2),
#   'Humidity': 87,
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 22.36,
#   'Wind Speed': 5.38},
#  {'City': 'margate',
#   'Cloudiness': 100,
#   'Country': 'GB',
#   'Date': datetime.datetime(2023, 9, 25, 22, 40, 11),
#   'Humidity': 84,
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 15.17,
#   'Wind Speed': 0.89},
#  {'City': 'alice springs',
#   'Cloudiness': 2,
#   'Country': 'AU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 2),
#   'Humidity': 30,
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 13.75,
#   'Wind Speed': 2.57},
#  {'City': 'nyurba',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 2),
#   'Humidity': 95,
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': 7.13,
#   'Wind Speed': 1.8},
#  {'City': 'gagliano del capo',
#   'Cloudiness': 100,
#   'Country': 'IT',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 2),
#   'Humidity': 77,
#   'Lat': 39.8442,
#   'Lng': 18.3695,
#   'Max Temp': 22.36,
#   'Wind Speed': 2.57},
#  {'City': 'punta arenas',
#   'Cloudiness': 0,
#   'Country': 'CL',
#   'Date': datetime.datetime(2023, 9, 25, 22, 42, 57),
#   'Humidity': 53,
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 9.06,
#   'Wind Speed': 11.32},
#  {'City': "komsomol'sk",
#   'Cloudiness': 10,
#   'Country': 'UA',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 3),
#   'Humidity': 38,
#   'Lat': 49.0097,
#   'Lng': 33.6455,
#   'Max Temp': 17.85,
#   'Wind Speed': 2.01},
#  {'City': 'vilyuchinsk',
#   'Cloudiness': 5,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 3),
#   'Humidity': 64,
#   'Lat': 52.9306,
#   'Lng': 158.4028,
#   'Max Temp': 11.15,
#   'Wind Speed': 8.26},
#  {'City': 'aykhal',
#   'Cloudiness': 5,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 3),
#   'Humidity': 81,
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 0.9,
#   'Wind Speed': 9.57},
#  {'City': 'port blair',
#   'Cloudiness': 40,
#   'Country': 'IN',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 19),
#   'Humidity': 94,
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 25.02,
#   'Wind Speed': 1.03},
#  {'City': "nar'yan-mar",
#   'Cloudiness': 32,
#   'Country': 'RU',
#   'Date': datetime.datetime(2023, 9, 25, 22, 47, 3),
#   'Humidity': 85,
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': 4.07,
#   'Wind Speed': 5.45},
#  {'City': 'sitka',
#   'Cloudiness': 40,
#   'Country': 'US',
#   'Date': datetime.datetime(2023, 9, 25, 22, 46, 28),
#   'Humidity': 48,
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 16.94,
#   'Wind Speed': 2.06}]
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          113
# Lat           113
# Lng           113
# Max Temp      113
# Humidity      113
# Cloudiness    113
# Wind Speed    113
# Country       113
# Date          113
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0  petropavlovsk-kamchatsky  53.0452  158.6483     10.33        62
# 1                  zaozersk  69.4005   32.4476      5.58        96
# 2                    newman  37.3138 -121.0208     26.19        19
# 3                      xiva  41.3783   60.3639     12.99        32
# 4            kyzyl-mazhalyk  51.1333   90.6000      2.75        53
#
#    Cloudiness  Wind Speed Country                Date
# 0          20        2.00      RU 2023-09-25 22:46:44
# 1         100        6.80      RU 2023-09-25 22:46:45
# 2          93        3.05      US 2023-09-25 22:46:45
# 3           0        2.86      UZ 2023-09-25 22:46:45
# 4          99        0.68      RU 2023-09-25 22:46:45

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        petropavlovsk-kamchatsky  53.0452  158.6483     10.33        62
# 1                        zaozersk  69.4005   32.4476      5.58        96
# 2                          newman  37.3138 -121.0208     26.19        19
# 3                            xiva  41.3783   60.3639     12.99        32
# 4                  kyzyl-mazhalyk  51.1333   90.6000      2.75        53
#
#          Cloudiness  Wind Speed Country                 Date
# City_ID
# 0                20        2.00      RU  2023-09-25 22:46:44
# 1               100        6.80      RU  2023-09-25 22:46:45
# 2                93        3.05      US  2023-09-25 22:46:45
# 3                 0        2.86      UZ  2023-09-25 22:46:45
# 4                99        0.68      RU  2023-09-25 22:46:45

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
 # Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")
# Show plot

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%Y-%m-%d"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")
# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
